# %%
import codex_search

# %%
codex_search.search_codex("Rename Column")
# Out:
# #1 [Python] Rename Column  ★★★★★
#    Rename a column in df
#    df = df.rename(columns={"old_name": "new_name"})
#
# #2 [Python] Drop column  ★★★★
#    Drop column by name from df
#    df = df.drop(columns=["col to remove"])
# df.drop(columns=["..."], inplace=True)
#
# #3 [Python] Return Prefixed Cols  ★★★★
#    Return only columns with specific prefix
#    df_filtered = df[df.columns[:3].tolist() + df.filter(like='pred_').columns.tolist()]
#
# #4 [Python] Select Cols by Position  ★★★★
#    Use index for returning columns based on position
#    df.iloc[:,4:]
#
# #5 [Python] Apply Conditional Category  ★★★★
#    Apply a label depending on value of another column
#    df["category"] = df.apply(
#     lambda row: "More missing labels" if row["Mean"] > row["Mean"] else "More wrong labels",
# ...
#
# #6 [Python] Subset on 2 Conditions  ★★★★★
#    Subset a dataframe according to two separate conditions
#    subset_df = df[(df['column_A'] > 50) & (df['column_B'] == 'Active')]
#
# ...

# %%
df = df.rename(columns={"old_name": "new_name"})
